# %%
from gaussian import GPWhiteNoise, GPLinear, GPConstant, GPSquaredExponential, GPMatern, GPPeriodic, GPRBF
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = "retina"
mystyle = "https://raw.githubusercontent.com/quantgirluk/matplotlib-stylesheets/main/quant-pastel-light.mplstyle"
plt.style.use(mystyle)

# %%
p = GPRBF(T=1.0, length_scale=0.1, sigma=1.0)
fig = p.plot_paths_and_kernel(n=100, N=5)

# %%
fig = p.plot_paths_and_kernel(n=100, N=5)

# %%
gp = GPRBF(T=2.0, length_scale=0.1, sigma=1.0)

from IPython.display import display
display(gp.make_widget(matrix_shape=True))
# Out:
# interactive(children=(FloatSlider(value=0.1, description='Length Scale', max=1.0, min=0.1), FloatSlider(value=…
# <function gaussian.GaussianLengthScaleSigma.make_widget.<locals>.update(length_scale, sigma, n_samples=5)>

# %%
gp = GPWhiteNoise(T=2.0, sigma=1.0)
imdisplay(gp.make_widget())
# Out:
# interactive(children=(FloatSlider(value=1.0, description='Sigma', max=3.0, min=0.25, step=0.25), IntSlider(val…
# <function gaussian.GaussianSigma.make_widget.<locals>.update(sigma=1.0, n_samples=5)>

# %%
import numpy as np

gp.covariance(times=np.linspace(0, 1.0, 5))
# Out:
# array([[9., 0., 0., 0., 0.],
#        [0., 9., 0., 0., 0.],
#        [0., 0., 9., 0., 0.],
#        [0., 0., 0., 9., 0.],
#        [0., 0., 0., 0., 9.]])
